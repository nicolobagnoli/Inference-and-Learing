# %% [markdown]
# # EE-411 TP session 11
#
# ## Part 1: Principal Component Analysis
#
# In this set of exercises we will play a little bit with PCA, first introducing it in a very simple case, and then showing its potential in an interesting example. PCA is fundamentally a dimensionality reduction algorithm, but it can also be useful as a tool for visualization, for noise filtering, for feature extraction and engineering, and much more.
#
# **What you will learn today:** In this notebook, we will see how to implement PCA using our old friend SciKitLearn.

# %%
#We import th usual packages
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sla

# %% [markdown]
# ## Introducing PCA
#
# _This excercise relies heavily on an example taken from the Python Data Science Handbook, by Jake VanderPlas_
#
# Principal component analysis is a fast and flexible unsupervised method for dimensionality reduction in data.
#
#  Its behavior is easier to visualize by looking at a two-dimensional dataset.
#
#  Let's consider the following 200 points in a 2D plane:

# %%
rng = np.random.RandomState(0) #initialize seed
X = np.dot(rng.rand(2, 2), rng.randn(2, 200)).T
plt.scatter(X[:, 0], X[:, 1]);

# %% [markdown]
# By eye, it is clear that there is a nearly linear relationship between the x and y variables, but the problem setting here is slightly different from the usual linear regression: rather than attempting to predict the y values from the x values, the unsupervised learning problem attempts to learn about the relationship between the x and y values.
#
# In PCA, this relationship is quantified by finding a list of the principal axes in the data, and using those axes to describe the dataset.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %% [markdown]
# Giving the dataset to the function `fit`, the model learns some quantities from the data, most importantly tha *components* and the *explained variance*:

# %%
pca.components_
# Out:
# array([[ 0.739393  ,  0.67327408],
#        [-0.67327408,  0.739393  ]])

# %%
pca.explained_variance_
# Out:
# array([1.48668691, 0.01057775])

# %% [markdown]
# To see what these numbers mean, let's visualize them as vectors over the input data, using the "components" to define the direction of the vector, and the "explained variance" to define the squared-length of the vector:

# %%
#to draw a vector going from the point v0 to the point v1
def draw_vector(v0, v1, ax=None):
    ax = ax or plt.gca()
    arrowprops=dict(arrowstyle='->',
                    linewidth=2,
                    shrinkA=0, shrinkB=0)
    ax.annotate('', v1, v0, arrowprops=arrowprops)

plt.figure(figsize=(14,7))
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
for length, vector in zip(pca.explained_variance_, pca.components_):
    v = vector * 3 * np.sqrt(length)
    draw_vector(pca.mean_, pca.mean_ + v)

# %% [markdown]
# These vectors represent the principal axes of the data, and the length of the vector is an indication of how "important" that axis is in describing the distribution of the data—more precisely, it is a measure of the variance of the data when projected onto that axis. The projection of each data point onto the principal axes are the "principal components" of the data.

# %% [markdown]
# ## Dimensionality reduction
#
# Using PCA for dimensionality reduction involves zeroing out one or more of the smallest principal components, resulting in a lower-dimensional projection of the data that preserves the maximal data variance.
#
# Here is an example of using PCA as a dimensionality reduction transform, using the same data as before:

# %%
pca = PCA(n_components=1)
pca.fit(X)
X_pca = pca.transform(X)
print("original shape:   ", X.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (200, 2)
# transformed shape: (200, 1)

# %% [markdown]
# The transformed data has been reduced to a single dimension. To understand the effect of this dimensionality reduction, we can perform the inverse transform of this reduced data and plot it along with the original data:

# %%
X_new = pca.inverse_transform(X_pca)
plt.figure(figsize=(14,7))
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.scatter(X_new[:, 0], X_new[:, 1], alpha=0.8)

# %% [markdown]
# This makes clear what a PCA dimensionality reduction means: the information along the least important principal axis or axes is removed, leaving only the component(s) of the data with the highest variance. The fraction of variance that is cut out (proportional to the spread of points about the line formed in this figure) is roughly a measure of how much "information" is discarded in this reduction of dimensionality.
#
# This reduced-dimension dataset is in some senses "good enough" to encode the most important relationships between the points: despite reducing the dimension of the data by 50%, the overall relationship between the data points are mostly preserved.

# %% [markdown]
# ## PCA as Noise filtering
#
# PCA can also be used as a filtering approach for noisy data. The idea is this: any components with variance much larger than the effect of the noise should be relatively unaffected by the noise. So if you reconstruct the data using just the largest subset of principal components, you should be preferentially keeping the signal and throwing out the noise.
#
# Let's see how this looks with the digits data. First we will plot several of the input noise-free data:

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape

def plot_digits(data):
    fig, axes = plt.subplots(4, 10, figsize=(10, 4),
                             subplot_kw={'xticks':[], 'yticks':[]},
                             gridspec_kw=dict(hspace=0.1, wspace=0.1))
    for i, ax in enumerate(axes.flat):
        ax.imshow(data[i].reshape(8, 8),
                  cmap='binary', interpolation='nearest',
                  clim=(0, 16))
plot_digits(digits.data)

# %% [markdown]
# Now lets add some random noise to create a noisy dataset, and re-plot it:

# %%
np.random.seed(42)
noisy = np.random.normal(digits.data, 4)
plot_digits(noisy)

# %% [markdown]
# It's clear by eye that the images are noisy, and contain spurious pixels. Let's train a PCA on the noisy data, requesting that the projection preserve 50% of the variance:

# %%
pca = PCA(0.50).fit(noisy)
pca.n_components_
# Out:
# 12

# %% [markdown]
# Here 50% of the variance amounts to 12 principal components. Now we compute these components, and then use the inverse of the transform to reconstruct the filtered digits:

# %%
components = pca.transform(noisy)
filtered = pca.inverse_transform(components)
plot_digits(filtered)

# %% [markdown]
# A vital part of using PCA in practice is the ability to estimate how many components are needed to describe the data. This can be determined by looking at the `cumulative explained variance ratio` as a function of the number of components:

# %%
pca = PCA().fit(digits.data)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# This curve quantifies how much of the total, 64-dimensional variance is contained within the first N components. For example, we see that with the digits the first 10 components contain approximately 75% of the variance, while you need around 50 components to describe close to 100% of the variance.

# %% [markdown]
# ### Your turn: Eigenfaces
#
# Download the *Labelled Faces in the Wild* (LFW) people dataset from sklearn. This dataset is a collection of pictures of famous people faces.
#
# By setting `min_faces_per_person=30`, the extracted dataset will only retain pictures of people that have at least 30 different pictures.

# %%
from sklearn.datasets import fetch_lfw_people

# Download the dataset

min_faces_per_person = 30

faces = fetch_lfw_people(min_faces_per_person=min_faces_per_person)

# %% [markdown]
# Now we plot the first 10 faces (`dataset.target_images`) together with the corresponding names (`dataset.target_names`) using
# `imshow`

# %%
# Print the first 10 faces with the corresponding names

for X, y in zip(faces.images[:10], faces.target[:10]):
    
    print(faces.target_names[y])
    plt.imshow(X)
    plt.show()
# Out:
# George W Bush
# Arnold Schwarzenegger
# Laura Bush
# George W Bush
# George W Bush
# Nestor Kirchner
# Arnold Schwarzenegger
# Lleyton Hewitt
# Colin Powell
# Lleyton Hewitt

# %%
print(f"There are {len(faces.data)} images in total, each composed by {len(faces.data[0])} pixels")
# Out:
# There are 2370 images in total, each composed by 2914 pixels

# %% [markdown]
# #### 1) In order to obtain a balanced dataset, keep only 30 pictures per person. Then, normalize your data in the range [0, 1].

# %%
from collections import Counter

counts = Counter(faces.target)  # count the number of elements for each target
mask = np.hstack([              # create a mask with the first 30 elements of each target, this will be used to filter the dataset
    np.where(faces.target == target_id)[0][:30]  #30 elements
    for target_id in counts.keys()
])

faces.images = faces.images[mask]   # filter the images
faces.data = faces.data[mask]       # filter the data
faces.target = faces.target[mask]   # filter the target
faces.target_names = faces.target_names  #keep the target names

print(f"Now there are {len(faces.images)} images.")

faces.data = faces.data / 255.0      # normalize the data by dividing by the maximum value of a pixel, 255.

print("Normalization complete. Data is now in the range [0, 1].")
# Out:
# Now there are 1020 images.
# Normalization complete. Data is now in the range [0, 1].

# %% [markdown]
# #### 2) Do the PCA on the new dataset, compute the principal components and print their shape

# %%
#PCA on the new dataset

n_components = 0.75 #chose like the example above
pca = PCA(n_components=n_components)
principal_components = pca.fit_transform(faces.data) # fit the model and apply the dimensionality reduction


print(f"Principal components shape: {principal_components.shape}")
# Out:
# Principal components shape: (1020, 22)

# %% [markdown]
# #### 3) Plot, using `imshow`, the first 5 principal components. How do they look like?

# %%
principal_component_images = pca.components_.reshape(-1, faces.images.shape[1], faces.images.shape[2]) #reshape the principal components to images as they are vectors

#plot the first 5 principal components
plt.figure(figsize=(15, 6))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(principal_component_images[i], cmap='gray')
    plt.title(f"PC {i + 1}")
    plt.axis('off')

plt.suptitle("First 5 Principal Components")
plt.show()

# %% [markdown]
# They look like very fuzzy face images but are not reconnectable to any of the famous people, I also would have excpected more like individual features like eyes but they all have some facial aspect in them.

# %% [markdown]
# #### 4) Plot the cumulative explained variance. How many principal components do we need in order to explain the majority of the variance of our faces?

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)  # calculate the cumulative explained variance


plt.figure(figsize=(10, 6))  # plot the cumulative explained variance
plt.plot(cumulative_variance, marker='o', linestyle='--', color='b')
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Principal Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid()

n_components_95 = np.argmax(cumulative_variance >= 0.95) + 1  # find the number of components that explain 95% of the variance
plt.axvline(x=n_components_95, color='r', linestyle='--', label=f"95% Variance: {n_components_95} PCs")
plt.legend()
plt.show()

# %% [markdown]
# We need just 1PC!!!

# %% [markdown]
# ## Evaluated Question
#
# #### 5) Compute and plot the projections of four pictures on the first {10, 30, 100, 300, 1000} principal components, using the parameter `n_components` and the method `inverse_transform`.

# %%
components_to_test = [10, 30, 100, 300, 1000]  # test different numbers of components as required

selected_images = faces.data[:4]  # select the first 4 images in the dataset

plt.figure(figsize=(15, 10))  # create a figure to plot the reconstructed images


for idx, n_components in enumerate(components_to_test):  # loop over the selected number of components
    pca = PCA(n_components=n_components)  #1- Create a PCA object with the selected number of components
    projected_data = pca.fit_transform(faces.data)  #2- Fit the PCA model and apply the dimensionality reduction
    reconstructed_images = pca.inverse_transform(projected_data[:4])  #3- Reconstruct the images using the inverse transform
    

    for i in range(4):  # Loop over the selected images
        plt.subplot(len(components_to_test), 4, idx * 4 + i + 1)  #arrange the subplots
        plt.imshow(reconstructed_images[i].reshape(faces.images.shape[1], faces.images.shape[2]), cmap='gray')
        plt.axis('off')
        if i == 0:
            plt.ylabel(f"{n_components} PCs", fontsize=12)

#title
plt.suptitle("Reconstructed Images Using Different Numbers of Principal Components", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Now, we are going to compare the performance of a naive classifier (the predicted label corresponds to the label of the nearest-neighbour image) when using the full pictures and the first 100 PCA projections.
#
# #### 6) First, split your data into a training and a test set.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(faces.data, faces.target, test_size=0.3,  random_state=42)

print(f"Training set size: {X_train.shape[0]} images")
print(f"Test set size: {X_test.shape[0]} images")
# Out:
# Training set size: 714 images
# Test set size: 306 images

# %% [markdown]
# #### 7) Use `sklearn.neighbors.KNeighbordClassifier` with `n_neighbors=1` to fit your training set. Evaluate the performance using the method score on the test set.

# %%
from sklearn.neighbors import KNeighborsClassifier

n_components = 714 #all the components
pca = PCA(n_components=n_components)

X_train_pca = pca.fit_transform(X_train)  #fit the PCA model and apply the dimensionality reduction
X_test_pca = pca.transform(X_test)  #transform the test set

#Train the 1-Nearest Neighbor classifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_pca, y_train)

#Evaluate performance
accuracy = knn.score(X_test_pca, y_test)  # Evaluate accuracy on the test set
print(f"Accuracy of 1-Nearest Neighbor Classifier: {accuracy * 100:.2f}%")
# Out:
# Accuracy of 1-Nearest Neighbor Classifier: 28.43%

# %% [markdown]
# #### 8) Now repeat the training but using only the first 100 principal components. Remember to project the test set also before evaluating the score. Compare with the previous score.

# %%
n_components = 100
pca = PCA(n_components=n_components)
X_train_pca = pca.fit_transform(X_train)  
X_test_pca = pca.transform(X_test)   


knn_pca = KNeighborsClassifier(n_neighbors=1)
knn_pca.fit(X_train_pca, y_train) 


accuracy_pca = knn_pca.score(X_test_pca, y_test) 
print(f"Accuracy with 100 principal components: {accuracy_pca * 100:.2f}%")
# Out:
# Accuracy with 100 principal components: 28.10%

# %% [markdown]
# Not alot of difference!!!

# %% [markdown]
# #### 9) When calling `PCA`, set the parameter `whiten=True`. This transformation, called ‘whitening’ and it rescales the principal components to have the same variance. Re-classify the faces and compare the accuracy with the previous ones.

# %%
n_components = 100
pca_whitened = PCA(n_components=n_components, whiten=True)  # Apply whitening
X_train_pca_whitened = pca_whitened.fit_transform(X_train)  
X_test_pca_whitened = pca_whitened.transform(X_test)        


knn_whitened = KNeighborsClassifier(n_neighbors=1)
knn_whitened.fit(X_train_pca_whitened, y_train) 


accuracy_whitened = knn_whitened.score(X_test_pca_whitened, y_test)  
print(f"Accuracy with whitened PCA (100 components): {accuracy_whitened * 100:.2f}%")
# Out:
# Accuracy with whitened PCA (100 components): 32.03%

# %% [markdown]
# Mutch better even than with the full PC!!!
